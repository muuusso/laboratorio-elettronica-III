# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.rcParams['figure.figsize'] = (8,6)
tau = 1e-3
R_1 = 1e6
R_2 = 1000
# G_ol = lambda s: 1 / (s*tau)**2 + 2*R_2/(R_1+R_2) * 1/(s*tau)

# x = np.linspace(-1000, 1000)*-1j
# plt.scatter(np.real(1 + G_ol(x)), np.imag(1 + G_ol(x)), marker='.')
y = np.linspace(-1e3, 1e3)
plt.plot(-y**2 * (R_1 + R_2)**2 / (2*R_2)**2, y)
plt.xlabel('Re', fontsize=14)
plt.ylabel('Img', fontsize=14)
plt.grid()
plt.show()
